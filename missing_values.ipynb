# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("character-deaths.csv")

# %%
data
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)             None       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo             None         NaN            NaN
# 913        Yurkhaz zo Yunzak             None       300.0            5.0
# 914         Yezzan Zo Qaggaz             None       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0              NaN                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2              NaN                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4              NaN                 NaN       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912            NaN                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]

# %%
data.isna().sum()
# Out:
# Name                    0
# Allegiances             0
# Death Year            612
# Book of Death         610
# Death Chapter         618
# Book Intro Chapter     12
# Gender                  0
# Nobility                0
# GoT                     0
# CoK                     0
# SoS                     0
# FfC                     0
# DwD                     0
# dtype: int64

# %%
df=data.fillna(0) ## 1. Replacing every NaN with 0

# %%
new_df["Book of Death"]
# Out:
# 0      0.0
# 1      3.0
# 2      0.0
# 3      5.0
# 4      0.0
#       ...
# 912    0.0
# 913    5.0
# 914    5.0
# 915    5.0
# 916    4.0
# Name: Book of Death, Length: 917, dtype: float64

# %%
## Sometimes replacing missing values with 0 might not be fine for the string data,
## like if we would have data for "Death Chapter" :First chapter, Second Chapter
## Replacing the NaN data with 0 will be not a good idea,
## So we would replace with the String Value "no chapter"
## whereas all other columns with missing data with 0 value

# %%
new_df1=data.fillna({
    "Death Year":0,
    "Book of Death":0,
    "Death Chapter": "no chapter",
    "Book Intro Chapter":0
    
})

# %%
new_df1["Death Chapter"]
# Out:
# 0      no chapter
# 1              51
# 2      no chapter
# 3              20
# 4      no chapter
#           ...
# 912    no chapter
# 913            59
# 914            57
# 915            73
# 916            29
# Name: Death Chapter, Length: 917, dtype: object

# %%
df1=data.fillna(method="ffill") ## Replaces missing values with the preceding value instead of having 0
df1
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)             None       299.0            3.0
# 2            Aegon Targaryen  House Targaryen       299.0            3.0
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister       300.0            5.0
# ..                       ...              ...         ...            ...
# 912                    Zollo             None       299.0            3.0
# 913        Yurkhaz zo Yunzak             None       300.0            5.0
# 914         Yezzan Zo Qaggaz             None       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0              NaN                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2             51.0                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4             20.0                20.0       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912           55.0                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]

# %%
df2=data.fillna(method="bfill") ## Replaces missing values with the following value instead of having 0
df2
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister       299.0            3.0
# 1    Aegon Frey (Jinglebell)             None       299.0            3.0
# 2            Aegon Targaryen  House Targaryen       300.0            5.0
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister       300.0            4.0
# ..                       ...              ...         ...            ...
# 912                    Zollo             None       300.0            5.0
# 913        Yurkhaz zo Yunzak             None       300.0            5.0
# 914         Yezzan Zo Qaggaz             None       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0             51.0                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2             20.0                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4             35.0                21.0       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912           59.0                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]

# %% [markdown]
# Personally, I don't think replacing methods with the previous or the following fields would make sense, especially with our data where the data is algorithmically sorted and replacing the death of year with the previous or forwading data would be really inaccurate.
#
# Maybe this method would be more appropriate for the data that does not vary so much and presented in the time-sorted way...But I think we need to be careful using that method.

# %%
df3=data.interpolate() ## interpolate() that, by default, performs linear interpolation at missing data points

# %%
df3["Death Year"]
# Out:
# 0         NaN
# 1      299.00
# 2      299.50
# 3      300.00
# 4      300.00
#         ...
# 912    299.75
# 913    300.00
# 914    300.00
# 915    300.00
# 916    300.00
# Name: Death Year, Length: 917, dtype: float64

# %%
df4=data.dropna()

# %%
df4
# Out:
#                                   Name    Allegiances  Death Year  \
# 1              Aegon Frey (Jinglebell)           None       299.0
# 3                        Adrack Humble  House Greyjoy       300.0
# 6    Aemon Targaryen (son of Maekar I)  Night's Watch       300.0
# 10                               Aggar  House Greyjoy       299.0
# 12                       Alan of Rosby  Night's Watch       300.0
# ..                                 ...            ...         ...
# 909                        Young Henly  Night's Watch       299.0
# 913                  Yurkhaz zo Yunzak           None       300.0
# 914                   Yezzan Zo Qaggaz           None       300.0
# 915                   Torwynd the Tame       Wildling       300.0
# 916                      Talbert Serry         Tyrell       300.0
#
#      Book of Death  Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  \
# 1              3.0           51.0                49.0       1         1    0
# 3              5.0           20.0                20.0       1         1    0
# 6              4.0           35.0                21.0       1         1    1
# 10             2.0           56.0                50.0       1         0    0
# 12             5.0            4.0                18.0       1         1    0
# ..             ...            ...                 ...     ...       ...  ...
# 909            3.0           55.0                55.0       1         0    0
# 913            5.0           59.0                47.0       1         0    0
# 914            5.0           57.0                25.0       1         1    0
# 915            5.0           73.0                73.0       1         0    0
# 916            4.0           29.0                29.0       1         1    0
#
#      CoK  SoS  FfC  DwD
# 1      0    1    0    0
# 3      0    0    0    1
# 6      0    1    1    0
# 10     1    0    0    0
# 12     1    1    0    1
# ..   ...  ...  ...  ...
# 909    0    1    0    0
# 913    0    0    0    1
# 914    0    0    0    1
# 915    0    1    0    0
# 916    0    0    1    0
#
# [292 rows x 13 columns]

# %%
data
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)             None       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo             None         NaN            NaN
# 913        Yurkhaz zo Yunzak             None       300.0            5.0
# 914         Yezzan Zo Qaggaz             None       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0              NaN                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2              NaN                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4              NaN                 NaN       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912            NaN                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]

# %%
## dropna() dropped more than 625 rows..

# %%
df5=data.dropna(thresh=2) 

## thresh=N requires that a column has at least N non-NaNs to survive.

# %%
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)             None       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo             None         NaN            NaN
# 913        Yurkhaz zo Yunzak             None       300.0            5.0
# 914         Yezzan Zo Qaggaz             None       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0              NaN                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2              NaN                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4              NaN                 NaN       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912            NaN                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]

# %%
data=data.replace("None", np.NaN)

# %%
data
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo              NaN         NaN            NaN
# 913        Yurkhaz zo Yunzak              NaN       300.0            5.0
# 914         Yezzan Zo Qaggaz              NaN       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0              NaN                56.0       1         1    1    1    1    1
# 1             51.0                49.0       1         1    0    0    1    0
# 2              NaN                 5.0       1         1    0    0    0    0
# 3             20.0                20.0       1         1    0    0    0    0
# 4              NaN                 NaN       1         1    0    0    1    0
# ..             ...                 ...     ...       ...  ...  ...  ...  ...
# 912            NaN                21.0       1         0    0    0    1    0
# 913           59.0                47.0       1         0    0    0    0    0
# 914           57.0                25.0       1         1    0    0    0    0
# 915           73.0                73.0       1         0    0    0    1    0
# 916           29.0                29.0       1         1    0    0    0    1
#
#      DwD
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
# ..   ...
# 912    0
# 913    1
# 914    1
# 915    0
# 916    0
#
# [917 rows x 13 columns]
